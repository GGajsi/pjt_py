# %% [markdown]
# ### pip install

# %%
from 함숨 import result

pip install somePakage
pip ununstall SomePackage

# %% [markdown]
# ### 특정 버전으로 설치하기

# %%
pip install SomePakage==1.0.4

pip install SomePakage

# %% [markdown]
# ### 최신버전으로 업그레이드

# %%
pip install --upgrade SomePakage

# %% [markdown]
# 설치된 패키지 확인하기

# %%
pip list

# %% [markdown]
# ### Faker

# %%
C:\> pip install Faker

# %% [markdown]
# ### sympy

# %%
from fractions import Fraction
import array

# %%
x = sympy.symbols("x")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x = sympy.symbols("x")
#
# NameError: name 'sympy' is not defined

# %%
x, y = sympy.symbols('x,y')

# %%
from fractions import Fraction

# %%
a = Fraction(1,5)
a
# Out:
# Fraction(1, 5)

# %%
a = Fraction('1 / 5')
a
# Out:
# Fraction(1, 5)

# %%
result = sympy.solve(f)
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 result = sympy.solve(f)
#       2 result
#
# NameError: name 'sympy' is not defined
