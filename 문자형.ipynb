# %%
 food = "I'm Lockey man"
 food
# Out:
# "I'm Lockey man"

# %%
food = 'pyton's favorite food is perl'
# Out:
#   Cell In[2], line 1
#     food = 'pyton's favorite food is perl'
#                                          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
food = "'메리아'는 살인자이다"
food
# Out:
# "'메리아'는 살인자이다"

# %% [markdown]
# 역슬레시\ 이용

# %%
food = 'py\'s favorite food is perl'
print(food)
# Out:
# py's favorite food is perl

# %%
multiLine = "Life is too short\n You need python"
print(multiLine)
# Out:
# Life is too short
#  You need python

# %%
multiLine = '''saksadi wdidjiqwjid dqwijdiq'''
print(multiLine)
# Out:
# saksadi wdidjiqwjid dqwijdiq

# %% [markdown]
# 문자열 곱하기

# %%
a = 'python'
a * 2
# Out:
# 'pythonpython'

# %%
print('='*10)
print('나는 대머리 망토')
print('='*10)
# Out:
# ...
# 나는 대머리 망토
# ...

# %% [markdown]
# 문자열 길이 구하기

# %%
본문 = "우리 I'm 회사는 이번년도에 100억을 벌어들임"
len(본문)
# Out:
# 26

# %% [markdown]
# 문자열 인덱싱과 슬라이싱.
# 파이썬은 0부터 센다.

# %%
a= 'Life is too short, You need Python'
a[2]
a[9]
a[-4]
a[-0]
# Out:
# 'L'

# %% [markdown]
# 문자열 포메팅

# %%
"I eat %d apples." %3
# Out:
# 'I eat 3 apples.'
