# %% [markdown]
# ### 모듈 만들기

# %%
from platform import python_branch
from turtledemo.forest import doit1

from 함숨 import result


def add(a, b):
    return a + b

def sub(a,b):
    return a - b

# %% [markdown]
# ### 모듈 불러오기

# %%
C:\Users\pahkey>cd C:\doit
C:\doit>dir
C:\doit>dir

import mod1
print(mod1.add(3,4))

print(mod1.sub(4,2))

# %% [markdown]
# ### if __name__ ==" __main__".의 의미

# %%
def add(a,b):
    return a + b

def sub(a,b):
    return a - b

print(add(1, 4))
print(add(4, 2))

# %%
C:\doit>python mod1.py

# %%
def add(a, b):
    return a + b

def sub(a, b):
    return a - b

if __name__ == "__main__":
    print(add(1,4))
    print(sub(4,2))

# %%
import  mod1

# %% [markdown]
# ### 클래스나 변수 등을 포함한 모듈

# %%
PI = 3.141592

class Matth:
    def solv(self, r):
        return PI * (r ** 2)

def add(a, b):
    return a + b

# %%
C:\Users\pahkey> cd C:\doit
C:\doit> python
import mod2
print(mod2.PI)

# %% [markdown]
# ### 다른 파일에서 모듈 불러오기

# %%
import mod2
result = mod2.add(3,4)
print(result)

# %% [markdown]
# ### 다른 디렉터리에 있는 모듈을ㅇ 불러오는 방법

# %%
C:\Users\pahkey>cd C:\doit
C:\doit>mkdir mymod
C:\doit>mpve mod2.py mymod

# %% [markdown]
# sys.path.append 사용하기

# %%
C:\doit>python
import sys

# %%
sys.path

# %%
sys.path.append("C:/doit/mymod")
sys.path

# %%
import mod2
print(mod2.add(3,4))

# %% [markdown]
# PYTHPATH 환경변수 사용하기

# %%
C:\doit>set PYTHONPATH = C:\doit\mymod
C:\doit>python
import mod2
print(mod2.add(3, 4))
