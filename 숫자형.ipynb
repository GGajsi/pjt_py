# %% [markdown]
# 정수형

# %%
a = 123
a = -178
a = 0

# %% [markdown]
# 실수형

# %%
a = 1.2
a = -45.34
a = 5.32E2
a
# Out:
# 532.0

# %% [markdown]
# 8진수와 16진수

# %%
a = 0o177
a

b = 0xa
b
# Out:
# 10

# %% [markdown]
# 사칙 연산

# %%
a = 3
b = 4
a + b
a - b
a * b
a / b
